# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 0 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    return x/255


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# **Hint:**
#
# Look into LabelBinarizer in the preprocessing module of sklearn.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    features = 10
    size = np.size(x)
    result = np.zeros([size,features])
    result[np.arange(size),x] = 1
    return result


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32,shape=[None,image_shape[0],image_shape[1],image_shape[2]],name='x')


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32,shape=[None,n_classes],name='y')


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32,name='keep_prob')


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.
#
# ** Hint: **
#
# When unpacking values as an argument in Python, look into the [unpacking](https://docs.python.org/3/tutorial/controlflow.html#unpacking-argument-lists) operator.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    channels = x_tensor.get_shape().as_list()[-1]
    
    conv_filter_size = [conv_ksize[0],conv_ksize[1],channels,conv_num_outputs]
    conv_stride_size = [1,conv_strides[0],conv_strides[1],1]
    pool_filter_size = [1,pool_ksize[0],pool_ksize[1],1]
    pool_stride_size = [1,pool_strides[0],pool_strides[1],1]
    
    
    #Weights and Bias for convolution
    weights = tf.Variable(tf.truncated_normal(conv_filter_size,stddev=0.1))
    bias = tf.Variable(tf.zeros([conv_num_outputs]))
    
    #Convolution Layer
    convolved = tf.nn.conv2d(x_tensor,weights,conv_stride_size,padding='SAME')
    
    #Nonlinearity and bias application
    h = tf.nn.relu(tf.add(convolved,bias))
    
    #Max pooling layer
    pool_layer = tf.nn.max_pool(h,pool_filter_size,pool_stride_size,padding='SAME')
    return pool_layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    batch_size,height,width,channels = x_tensor.get_shape().as_list()
    return tf.reshape(x_tensor,shape=[-1,height*width*channels])


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    
    #I'll implement without the shortcut for the learning experience (woohoo!)
    values_size = x_tensor.get_shape().as_list()[-1]
    W = tf.Variable(tf.truncated_normal([values_size,num_outputs],stddev=0.1))
    B = tf.Variable(tf.zeros([num_outputs]))
    h = tf.nn.relu(tf.add(tf.matmul(x_tensor,W),B))
    return h


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    values_size = x_tensor.get_shape().as_list()[-1]
    W = tf.Variable(tf.truncated_normal([values_size,num_outputs],stddev=0.1))
    B = tf.Variable(tf.zeros([num_outputs]))
    
    output = tf.add(tf.matmul(x_tensor,W),B)
    return output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    
    #5x5,4x4
    conv1 = conv2d_maxpool(x,16,(3,3),(1,1),(3,3),(2,2))
    #3x3,2x2
    conv2 = conv2d_maxpool(conv1,32,(2,2),(1,1),(2,2),(1,1))
    #1x1,2x2
    conv3 = conv2d_maxpool(conv2,64,(1,1),(1,1),(2,2),(1,1))

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    flattened = flatten(conv3)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    
    fc1 = tf.nn.dropout(fully_conn(flattened,200),keep_prob=keep_prob)
    
    fc2 = tf.nn.dropout(fully_conn(fc1,100),keep_prob=keep_prob)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    o = output(fc2,10)
    
    # TODO: return output
    return o


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    
    
    session.run(optimizer,feed_dict={x:feature_batch,y:label_batch,keep_prob:keep_probability})

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    current_train_cost,current_train_accuracy = sess.run([cost,accuracy],feed_dict={x:feature_batch,y:label_batch,keep_prob:1})
    current_validation_cost,current_validation_accuracy = sess.run([cost,accuracy],feed_dict={x:valid_features,y:valid_labels,keep_prob:1})
    print("\nCurrent Training Cost is {}\nCurrent Accuracy is {}\n".format(current_train_cost,current_train_accuracy))
    print("Current Validation Cost is {}\nCurrent Validation Accuracy is {}\n".format(current_validation_cost,current_validation_accuracy))
    print("-------------------------------------------------------------------------------------")

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 25
batch_size = 128
keep_probability = 0.6

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.initialize_all_variables())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:
# Current Training Cost is 2.0231165885925293
# Current Accuracy is 0.30000001192092896
#
# Current Validation Cost is 1.8752175569534302
# Current Validation Accuracy is 0.3569999933242798
#
# -------------------------------------------------------------------------------------
# Epoch  2, CIFAR-10 Batch 1:
# Current Training Cost is 1.8123366832733154
# Current Accuracy is 0.42500001192092896
#
# Current Validation Cost is 1.6205222606658936
# Current Validation Accuracy is 0.41780000925064087
#
# -------------------------------------------------------------------------------------
# Epoch  3, CIFAR-10 Batch 1:
# Current Training Cost is 1.6549514532089233
# Current Accuracy is 0.44999998807907104
#
# Current Validation Cost is 1.5088087320327759
# Current Validation Accuracy is 0.451200008392334
#
# -------------------------------------------------------------------------------------
# Epoch  4, CIFAR-10 Batch 1:
# Current Training Cost is 1.5510971546173096
# Current Accuracy is 0.42500001192092896
#
# Current Validation Cost is 1.414939045906067
# Current Validation Accuracy is 0.49160000681877136
#
# -------------------------------------------------------------------------------------
# Epoch  5, CIFAR-10 Batch 1:
# Current Training Cost is 1.4063695669174194
# Current Accuracy is 0.5249999761581421
#
# Current Validation Cost is 1.3996433019638062
# Current Validation Accuracy is 0.48980000615119934
#
# -------------------------------------------------------------------------------------
# Epoch  6, CIFAR-10 Batch 1:
# Current Training Cost is 1.2591084241867065
# Current Accuracy is 0.550000011920929
#
# Current Validation Cost is 1.3259570598602295
# Current Validation Accuracy is 0.5210000276565552
#
# -------------------------------------------------------------------------------------
# Epoch  7, CIFAR-10 Batch 1:
# Current Training Cost is 1.1178566217422485
# Current Accuracy is 0.574999988079071
#
# Current Validation Cost is 1.3149359226226807
# Current Validation Accuracy is 0.5194000005722046
#
# -------------------------------------------------------------------------------------
# Epoch  8, CIFAR-10 Batch 1:
# Current Training Cost is 1.060144066810608
# Current Accuracy is 0.6499999761581421
#
# Current Validation Cost is 1.3330726623535156
# Current Validation Accuracy is 0.5235999822616577
#
# -------------------------------------------------------------------------------------
# Epoch  9, CIFAR-10 Batch 1:
# Current Training Cost is 0.9052294492721558
# Current Accuracy is 0.6499999761581421
#
# Current Validation Cost is 1.2919368743896484
# Current Validation Accuracy is 0.5332000255584717
#
# -------------------------------------------------------------------------------------
# Epoch 10, CIFAR-10 Batch 1:
# Current Training Cost is 0.8393455743789673
# Current Accuracy is 0.75
#
# Current Validation Cost is 1.2357131242752075
# Current Validation Accuracy is 0.550000011920929
#
# -------------------------------------------------------------------------------------
# Epoch 11, CIFAR-10 Batch 1:
# Current Training Cost is 0.7517696619033813
# Current Accuracy is 0.699999988079071
#
# Current Validation Cost is 1.248548984527588
# Current Validation Accuracy is 0.5493999719619751
#
# -------------------------------------------------------------------------------------
# Epoch 12, CIFAR-10 Batch 1:
# Current Training Cost is 0.7446342706680298
# Current Accuracy is 0.7250000238418579
#
# Current Validation Cost is 1.2107162475585938
# Current Validation Accuracy is 0.5720000267028809
#
# -------------------------------------------------------------------------------------
# Epoch 13, CIFAR-10 Batch 1:
# Current Training Cost is 0.6933100819587708
# Current Accuracy is 0.800000011920929
#
# Current Validation Cost is 1.2073876857757568
# Current Validation Accuracy is 0.5648000240325928
#
# -------------------------------------------------------------------------------------
# Epoch 14, CIFAR-10 Batch 1:
# Current Training Cost is 0.6099056005477905
# Current Accuracy is 0.800000011920929
#
# Current Validation Cost is 1.1898193359375
# Current Validation Accuracy is 0.5776000022888184
#
# -------------------------------------------------------------------------------------
# Epoch 15, CIFAR-10 Batch 1:
# Current Training Cost is 0.6121648550033569
# Current Accuracy is 0.7749999761581421
#
# Current Validation Cost is 1.205805778503418
# Current Validation Accuracy is 0.5803999900817871
#
# -------------------------------------------------------------------------------------
# Epoch 16, CIFAR-10 Batch 1:
# Current Training Cost is 0.5173537135124207
# Current Accuracy is 0.7749999761581421
#
# Current Validation Cost is 1.1970646381378174
# Current Validation Accuracy is 0.5830000042915344
#
# -------------------------------------------------------------------------------------
# Epoch 17, CIFAR-10 Batch 1:
# Current Training Cost is 0.45243039727211
# Current Accuracy is 0.824999988079071
#
# Current Validation Cost is 1.2467306852340698
# Current Validation Accuracy is 0.5763999819755554
#
# -------------------------------------------------------------------------------------
# Epoch 18, CIFAR-10 Batch 1:
# Current Training Cost is 0.4379653036594391
# Current Accuracy is 0.8999999761581421
#
# Current Validation Cost is 1.285793662071228
# Current Validation Accuracy is 0.5669999718666077
#
# -------------------------------------------------------------------------------------
# Epoch 19, CIFAR-10 Batch 1:
# Current Training Cost is 0.410346657037735
# Current Accuracy is 0.824999988079071
#
# Current Validation Cost is 1.2421343326568604
# Current Validation Accuracy is 0.5853999853134155
#
# -------------------------------------------------------------------------------------
# Epoch 20, CIFAR-10 Batch 1:
# Current Training Cost is 0.3540361821651459
# Current Accuracy is 0.925000011920929
#
# Current Validation Cost is 1.2833309173583984
# Current Validation Accuracy is 0.5857999920845032
#
# -------------------------------------------------------------------------------------
# Epoch 21, CIFAR-10 Batch 1:
# Current Training Cost is 0.30885401368141174
# Current Accuracy is 0.925000011920929
#
# Current Validation Cost is 1.2065304517745972
# Current Validation Accuracy is 0.6015999913215637
#
# -------------------------------------------------------------------------------------
# Epoch 22, CIFAR-10 Batch 1:
# Current Training Cost is 0.29368752241134644
# Current Accuracy is 0.925000011920929
#
# Current Validation Cost is 1.2137067317962646
# Current Validation Accuracy is 0.5946000218391418
#
# -------------------------------------------------------------------------------------
# Epoch 23, CIFAR-10 Batch 1:
# Current Training Cost is 0.2571079432964325
# Current Accuracy is 0.949999988079071
#
# Current Validation Cost is 1.2610390186309814
# Current Validation Accuracy is 0.598800003528595
#
# -------------------------------------------------------------------------------------
# Epoch 24, CIFAR-10 Batch 1:
# Current Training Cost is 0.21974511444568634
# Current Accuracy is 0.949999988079071
#
# Current Validation Cost is 1.2810593843460083
# Current Validation Accuracy is 0.5946000218391418
#
# -------------------------------------------------------------------------------------
# Epoch 25, CIFAR-10 Batch 1:
# Current Training Cost is 0.2115797996520996
# Current Accuracy is 0.9750000238418579
#
# Current Validation Cost is 1.2761163711547852
# Current Validation Accuracy is 0.5893999934196472
#
# -------------------------------------------------------------------------------------

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.initialize_all_variables())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:
# Current Training Cost is 2.0590415000915527
# Current Accuracy is 0.125
#
# Current Validation Cost is 1.9086158275604248
# Current Validation Accuracy is 0.2842000126838684
#
# -------------------------------------------------------------------------------------
# Epoch  1, CIFAR-10 Batch 2:
# Current Training Cost is 1.6490144729614258
# Current Accuracy is 0.4000000059604645
#
# Current Validation Cost is 1.6583150625228882
# Current Validation Accuracy is 0.4059999883174896
#
# -------------------------------------------------------------------------------------
# Epoch  1, CIFAR-10 Batch 3:
# Current Training Cost is 1.3713994026184082
# Current Accuracy is 0.4749999940395355
#
# Current Validation Cost is 1.5371603965759277
# Current Validation Accuracy is 0.43160000443458557
#
# -------------------------------------------------------------------------------------
# Epoch  1, CIFAR-10 Batch 4:
# Current Training Cost is 1.4174491167068481
# Current Accuracy is 0.4749999940395355
#
# Current Validation Cost is 1.404605507850647
# Current Validation Accuracy is 0.48739999532699585
#
# -------------------------------------------------------------------------------------
# Epoch  1, CIFAR-10 Batch 5:
# Current Training Cost is 1.4144058227539062
# Current Accuracy is 0.5249999761581421
#
# Current Validation Cost is 1.3454556465148926
# Current Validation Accuracy is 0.508400022983551
#
# -------------------------------------------------------------------------------------
# Epoch  2, CIFAR-10 Batch 1:
# Current Training Cost is 1.2891862392425537
# Current Accuracy is 0.625
#
# Current Validation Cost is 1.3173298835754395
# Current Validation Accuracy is 0.5267999768257141
#
# -------------------------------------------------------------------------------------
# Epoch  2, CIFAR-10 Batch 2:
# Current Training Cost is 1.2419278621673584
# Current Accuracy is 0.6000000238418579
#
# Current Validation Cost is 1.3037242889404297
# Current Validation Accuracy is 0.5296000242233276
#
# -------------------------------------------------------------------------------------
# Epoch  2, CIFAR-10 Batch 3:
# Current Training Cost is 1.0604654550552368
# Current Accuracy is 0.625
#
# Current Validation Cost is 1.2364726066589355
# Current Validation Accuracy is 0.545799970626831
#
# -------------------------------------------------------------------------------------
# Epoch  2, CIFAR-10 Batch 4:
# Current Training Cost is 1.1411418914794922
# Current Accuracy is 0.6000000238418579
#
# Current Validation Cost is 1.2424604892730713
# Current Validation Accuracy is 0.553600013256073
#
# -------------------------------------------------------------------------------------
# Epoch  2, CIFAR-10 Batch 5:
# Current Training Cost is 1.0939489603042603
# Current Accuracy is 0.699999988079071
#
# Current Validation Cost is 1.168272614479065
# Current Validation Accuracy is 0.5817999839782715
#
# -------------------------------------------------------------------------------------
# Epoch  3, CIFAR-10 Batch 1:
# Current Training Cost is 1.1253770589828491
# Current Accuracy is 0.550000011920929
#
# Current Validation Cost is 1.2668167352676392
# Current Validation Accuracy is 0.5550000071525574
#
# -------------------------------------------------------------------------------------
# Epoch  3, CIFAR-10 Batch 2:
# Current Training Cost is 0.9943537712097168
# Current Accuracy is 0.699999988079071
#
# Current Validation Cost is 1.1459306478500366
# Current Validation Accuracy is 0.5965999960899353
#
# -------------------------------------------------------------------------------------
# Epoch  3, CIFAR-10 Batch 3:
# Current Training Cost is 0.9951971769332886
# Current Accuracy is 0.7250000238418579
#
# Current Validation Cost is 1.1329425573349
# Current Validation Accuracy is 0.5925999879837036
#
# -------------------------------------------------------------------------------------
# Epoch  3, CIFAR-10 Batch 4:
# Current Training Cost is 0.9764154553413391
# Current Accuracy is 0.699999988079071
#
# Current Validation Cost is 1.096842885017395
# Current Validation Accuracy is 0.6177999973297119
#
# -------------------------------------------------------------------------------------
# Epoch  3, CIFAR-10 Batch 5:
# Current Training Cost is 0.911429226398468
# Current Accuracy is 0.7250000238418579
#
# Current Validation Cost is 1.0980197191238403
# Current Validation Accuracy is 0.6074000000953674
#
# -------------------------------------------------------------------------------------
# Epoch  4, CIFAR-10 Batch 1:
# Current Training Cost is 0.9361621737480164
# Current Accuracy is 0.6499999761581421
#
# Current Validation Cost is 1.0910999774932861
# Current Validation Accuracy is 0.6169999837875366
#
# -------------------------------------------------------------------------------------
# Epoch  4, CIFAR-10 Batch 2:
# Current Training Cost is 0.8478177189826965
# Current Accuracy is 0.699999988079071
#
# Current Validation Cost is 1.0612002611160278
# Current Validation Accuracy is 0.6245999932289124
#
# -------------------------------------------------------------------------------------
# Epoch  4, CIFAR-10 Batch 3:
# Current Training Cost is 0.7698372602462769
# Current Accuracy is 0.7749999761581421
#
# Current Validation Cost is 1.0461267232894897
# Current Validation Accuracy is 0.6215999722480774
#
# -------------------------------------------------------------------------------------
# Epoch  4, CIFAR-10 Batch 4:
# Current Training Cost is 0.8433321714401245
# Current Accuracy is 0.7250000238418579
#
# Current Validation Cost is 1.028324842453003
# Current Validation Accuracy is 0.6313999891281128
#
# -------------------------------------------------------------------------------------
# Epoch  4, CIFAR-10 Batch 5:
# Current Training Cost is 0.8250523805618286
# Current Accuracy is 0.7749999761581421
#
# Current Validation Cost is 1.0236870050430298
# Current Validation Accuracy is 0.6434000134468079
#
# -------------------------------------------------------------------------------------
# Epoch  5, CIFAR-10 Batch 1:
# Current Training Cost is 0.8032224774360657
# Current Accuracy is 0.7250000238418579
#
# Current Validation Cost is 1.0375250577926636
# Current Validation Accuracy is 0.6281999945640564
#
# -------------------------------------------------------------------------------------
# Epoch  5, CIFAR-10 Batch 2:
# Current Training Cost is 0.761983335018158
# Current Accuracy is 0.7749999761581421
#
# Current Validation Cost is 0.985451340675354
# Current Validation Accuracy is 0.6588000059127808
#
# -------------------------------------------------------------------------------------
# Epoch  5, CIFAR-10 Batch 3:
# Current Training Cost is 0.6976715326309204
# Current Accuracy is 0.8500000238418579
#
# Current Validation Cost is 1.0217676162719727
# Current Validation Accuracy is 0.6407999992370605
#
# -------------------------------------------------------------------------------------
# Epoch  5, CIFAR-10 Batch 4:
# Current Training Cost is 0.7404763698577881
# Current Accuracy is 0.800000011920929
#
# Current Validation Cost is 1.0096687078475952
# Current Validation Accuracy is 0.646399974822998
#
# -------------------------------------------------------------------------------------
# Epoch  5, CIFAR-10 Batch 5:
# Current Training Cost is 0.7133632302284241
# Current Accuracy is 0.824999988079071
#
# Current Validation Cost is 0.9665458798408508
# Current Validation Accuracy is 0.6574000120162964
#
# -------------------------------------------------------------------------------------
# Epoch  6, CIFAR-10 Batch 1:
# Current Training Cost is 0.7640111446380615
# Current Accuracy is 0.6499999761581421
#
# Current Validation Cost is 0.9922658205032349
# Current Validation Accuracy is 0.651199996471405
#
# -------------------------------------------------------------------------------------
# Epoch  6, CIFAR-10 Batch 2:
# Current Training Cost is 0.6720443964004517
# Current Accuracy is 0.7749999761581421
#
# Current Validation Cost is 0.9721912145614624
# Current Validation Accuracy is 0.656000018119812
#
# -------------------------------------------------------------------------------------
# Epoch  6, CIFAR-10 Batch 3:
# Current Training Cost is 0.566453218460083
# Current Accuracy is 0.8999999761581421
#
# Current Validation Cost is 0.9811400175094604
# Current Validation Accuracy is 0.6553999781608582
#
# -------------------------------------------------------------------------------------
# Epoch  6, CIFAR-10 Batch 4:
# Current Training Cost is 0.593281626701355
# Current Accuracy is 0.800000011920929
#
# Current Validation Cost is 1.0138156414031982
# Current Validation Accuracy is 0.6417999863624573
#
# -------------------------------------------------------------------------------------
# Epoch  6, CIFAR-10 Batch 5:
# Current Training Cost is 0.605154275894165
# Current Accuracy is 0.824999988079071
#
# Current Validation Cost is 0.9965255856513977
# Current Validation Accuracy is 0.651199996471405
#
# -------------------------------------------------------------------------------------
# Epoch  7, CIFAR-10 Batch 1:
# Current Training Cost is 0.647395133972168
# Current Accuracy is 0.75
#
# Current Validation Cost is 0.9429216980934143
# Current Validation Accuracy is 0.6693999767303467
#
# -------------------------------------------------------------------------------------
# Epoch  7, CIFAR-10 Batch 2:
# Current Training Cost is 0.6182736158370972
# Current Accuracy is 0.824999988079071
#
# Current Validation Cost is 0.9399433732032776
# Current Validation Accuracy is 0.66839998960495
#
# -------------------------------------------------------------------------------------
# Epoch  7, CIFAR-10 Batch 3:
# Current Training Cost is 0.507712185382843
# Current Accuracy is 0.7749999761581421
#
# Current Validation Cost is 0.9376468658447266
# Current Validation Accuracy is 0.6787999868392944
#
# -------------------------------------------------------------------------------------
# Epoch  7, CIFAR-10 Batch 4:
# Current Training Cost is 0.5617495775222778
# Current Accuracy is 0.8500000238418579
#
# Current Validation Cost is 1.0027090311050415
# Current Validation Accuracy is 0.6431999802589417
#
# -------------------------------------------------------------------------------------
# Epoch  7, CIFAR-10 Batch 5:
# Current Training Cost is 0.4969322681427002
# Current Accuracy is 0.8500000238418579
#
# Current Validation Cost is 0.9469142556190491
# Current Validation Accuracy is 0.675000011920929
#
# -------------------------------------------------------------------------------------
# Epoch  8, CIFAR-10 Batch 1:
# Current Training Cost is 0.5825995206832886
# Current Accuracy is 0.75
#
# Current Validation Cost is 0.9364648461341858
# Current Validation Accuracy is 0.675599992275238
#
# -------------------------------------------------------------------------------------
# Epoch  8, CIFAR-10 Batch 2:
# Current Training Cost is 0.5110645294189453
# Current Accuracy is 0.824999988079071
#
# Current Validation Cost is 0.9133256077766418
# Current Validation Accuracy is 0.6801999807357788
#
# -------------------------------------------------------------------------------------
# Epoch  8, CIFAR-10 Batch 3:
# Current Training Cost is 0.4386604428291321
# Current Accuracy is 0.875
#
# Current Validation Cost is 0.932807981967926
# Current Validation Accuracy is 0.6772000193595886
#
# -------------------------------------------------------------------------------------
# Epoch  8, CIFAR-10 Batch 4:
# Current Training Cost is 0.4981497824192047
# Current Accuracy is 0.8999999761581421
#
# Current Validation Cost is 0.9843427538871765
# Current Validation Accuracy is 0.6553999781608582
#
# -------------------------------------------------------------------------------------
# Epoch  8, CIFAR-10 Batch 5:
# Current Training Cost is 0.4721077084541321
# Current Accuracy is 0.824999988079071
#
# Current Validation Cost is 0.9093120098114014
# Current Validation Accuracy is 0.6850000023841858
#
# -------------------------------------------------------------------------------------
# Epoch  9, CIFAR-10 Batch 1:
# Current Training Cost is 0.5212497711181641
# Current Accuracy is 0.824999988079071
#
# Current Validation Cost is 0.9279346466064453
# Current Validation Accuracy is 0.678600013256073
#
# -------------------------------------------------------------------------------------
# Epoch  9, CIFAR-10 Batch 2:
# Current Training Cost is 0.4765644967556
# Current Accuracy is 0.8500000238418579
#
# Current Validation Cost is 0.9123048782348633
# Current Validation Accuracy is 0.6823999881744385
#
# -------------------------------------------------------------------------------------
# Epoch  9, CIFAR-10 Batch 3:
# Current Training Cost is 0.37452587485313416
# Current Accuracy is 0.875
#
# Current Validation Cost is 0.9275136590003967
# Current Validation Accuracy is 0.6845999956130981
#
# -------------------------------------------------------------------------------------
# Epoch  9, CIFAR-10 Batch 4:
# Current Training Cost is 0.4565826952457428
# Current Accuracy is 0.925000011920929
#
# Current Validation Cost is 0.9603908061981201
# Current Validation Accuracy is 0.6687999963760376
#
# -------------------------------------------------------------------------------------
# Epoch  9, CIFAR-10 Batch 5:
# Current Training Cost is 0.4074672758579254
# Current Accuracy is 0.875
#
# Current Validation Cost is 0.8908017873764038
# Current Validation Accuracy is 0.6919999718666077
#
# -------------------------------------------------------------------------------------
# Epoch 10, CIFAR-10 Batch 1:
# Current Training Cost is 0.4567790627479553
# Current Accuracy is 0.8500000238418579
#
# Current Validation Cost is 0.9197572469711304
# Current Validation Accuracy is 0.6836000084877014
#
# -------------------------------------------------------------------------------------
# Epoch 10, CIFAR-10 Batch 2:
# Current Training Cost is 0.387864887714386
# Current Accuracy is 0.8500000238418579
#
# Current Validation Cost is 0.8791066408157349
# Current Validation Accuracy is 0.6930000185966492
#
# -------------------------------------------------------------------------------------
# Epoch 10, CIFAR-10 Batch 3:
# Current Training Cost is 0.3056606650352478
# Current Accuracy is 0.949999988079071
#
# Current Validation Cost is 0.9205834865570068
# Current Validation Accuracy is 0.6858000159263611
#
# -------------------------------------------------------------------------------------
# Epoch 10, CIFAR-10 Batch 4:
# Current Training Cost is 0.3543769121170044
# Current Accuracy is 0.949999988079071
#
# Current Validation Cost is 0.8774570226669312
# Current Validation Accuracy is 0.699999988079071
#
# -------------------------------------------------------------------------------------
# Epoch 10, CIFAR-10 Batch 5:
# Current Training Cost is 0.3394039571285248
# Current Accuracy is 0.949999988079071
#
# Current Validation Cost is 0.8663509488105774
# Current Validation Accuracy is 0.7020000219345093
#
# -------------------------------------------------------------------------------------
# Epoch 11, CIFAR-10 Batch 1:
# Current Training Cost is 0.39065462350845337
# Current Accuracy is 0.8999999761581421
#
# Current Validation Cost is 0.9220935702323914
# Current Validation Accuracy is 0.6855999827384949
#
# -------------------------------------------------------------------------------------
# Epoch 11, CIFAR-10 Batch 2:
# Current Training Cost is 0.366119921207428
# Current Accuracy is 0.875
#
# Current Validation Cost is 0.8843111395835876
# Current Validation Accuracy is 0.6966000199317932
#
# -------------------------------------------------------------------------------------
# Epoch 11, CIFAR-10 Batch 3:
# Current Training Cost is 0.2595304548740387
# Current Accuracy is 0.949999988079071
#
# Current Validation Cost is 0.9056907296180725
# Current Validation Accuracy is 0.6862000226974487
#
# -------------------------------------------------------------------------------------
# Epoch 11, CIFAR-10 Batch 4:
# Current Training Cost is 0.3241528868675232
# Current Accuracy is 0.949999988079071
#
# Current Validation Cost is 0.8990457057952881
# Current Validation Accuracy is 0.6866000294685364
#
# -------------------------------------------------------------------------------------
# Epoch 11, CIFAR-10 Batch 5:
# Current Training Cost is 0.2710426449775696
# Current Accuracy is 0.949999988079071
#
# Current Validation Cost is 0.8517187237739563
# Current Validation Accuracy is 0.7049999833106995
#
# -------------------------------------------------------------------------------------
# Epoch 12, CIFAR-10 Batch 1:
# Current Training Cost is 0.37974342703819275
# Current Accuracy is 0.875
#
# Current Validation Cost is 0.8907421827316284
# Current Validation Accuracy is 0.7056000232696533
#
# -------------------------------------------------------------------------------------
# Epoch 12, CIFAR-10 Batch 2:
# Current Training Cost is 0.3389296233654022
# Current Accuracy is 0.8999999761581421
#
# Current Validation Cost is 0.8679177761077881
# Current Validation Accuracy is 0.7003999948501587
#
# -------------------------------------------------------------------------------------
# Epoch 12, CIFAR-10 Batch 3:
# Current Training Cost is 0.24453969299793243
# Current Accuracy is 0.9750000238418579
#
# Current Validation Cost is 0.9404168128967285
# Current Validation Accuracy is 0.6790000200271606
#
# -------------------------------------------------------------------------------------
# Epoch 12, CIFAR-10 Batch 4:
# Current Training Cost is 0.3004482388496399
# Current Accuracy is 0.925000011920929
#
# Current Validation Cost is 0.8976507782936096
# Current Validation Accuracy is 0.6901999711990356
#
# -------------------------------------------------------------------------------------
# Epoch 12, CIFAR-10 Batch 5:
# Current Training Cost is 0.2944323420524597
# Current Accuracy is 0.9750000238418579
#
# Current Validation Cost is 0.8760536909103394
# Current Validation Accuracy is 0.7024000287055969
#
# -------------------------------------------------------------------------------------
# Epoch 13, CIFAR-10 Batch 1:
# Current Training Cost is 0.34174686670303345
# Current Accuracy is 0.8500000238418579
#
# Current Validation Cost is 0.879252552986145
# Current Validation Accuracy is 0.7039999961853027
#
# -------------------------------------------------------------------------------------
# Epoch 13, CIFAR-10 Batch 2:
# Current Training Cost is 0.32673224806785583
# Current Accuracy is 0.8999999761581421
#
# Current Validation Cost is 0.8986037373542786
# Current Validation Accuracy is 0.6970000267028809
#
# -------------------------------------------------------------------------------------
# Epoch 13, CIFAR-10 Batch 3:
# Current Training Cost is 0.2205715924501419
# Current Accuracy is 0.925000011920929
#
# Current Validation Cost is 0.9004730582237244
# Current Validation Accuracy is 0.6985999941825867
#
# -------------------------------------------------------------------------------------
# Epoch 13, CIFAR-10 Batch 4:
# Current Training Cost is 0.28424105048179626
# Current Accuracy is 0.949999988079071
#
# Current Validation Cost is 0.8795185685157776
# Current Validation Accuracy is 0.704200029373169
#
# -------------------------------------------------------------------------------------
# Epoch 13, CIFAR-10 Batch 5:
# Current Training Cost is 0.26666513085365295
# Current Accuracy is 0.9750000238418579
#
# Current Validation Cost is 0.8922808766365051
# Current Validation Accuracy is 0.6949999928474426
#
# -------------------------------------------------------------------------------------
# Epoch 14, CIFAR-10 Batch 1:
# Current Training Cost is 0.33394375443458557
# Current Accuracy is 0.925000011920929
#
# Current Validation Cost is 0.8592850565910339
# Current Validation Accuracy is 0.7107999920845032
#
# -------------------------------------------------------------------------------------
# Epoch 14, CIFAR-10 Batch 2:
# Current Training Cost is 0.27533963322639465
# Current Accuracy is 0.925000011920929
#
# Current Validation Cost is 0.8754673004150391
# Current Validation Accuracy is 0.7027999758720398
#
# -------------------------------------------------------------------------------------
# Epoch 14, CIFAR-10 Batch 3:
# Current Training Cost is 0.17490026354789734
# Current Accuracy is 0.9750000238418579
#
# Current Validation Cost is 0.8947963118553162
# Current Validation Accuracy is 0.7003999948501587
#
# -------------------------------------------------------------------------------------
# Epoch 14, CIFAR-10 Batch 4:
# Current Training Cost is 0.2073696106672287
# Current Accuracy is 0.9750000238418579
#
# Current Validation Cost is 0.8618398308753967
# Current Validation Accuracy is 0.7093999981880188
#
# -------------------------------------------------------------------------------------
# Epoch 14, CIFAR-10 Batch 5:
# Current Training Cost is 0.23092901706695557
# Current Accuracy is 0.9750000238418579
#
# Current Validation Cost is 0.8972787857055664
# Current Validation Accuracy is 0.6949999928474426
#
# -------------------------------------------------------------------------------------
# Epoch 15, CIFAR-10 Batch 1:
# Current Training Cost is 0.2807404398918152
# Current Accuracy is 0.925000011920929
#
# Current Validation Cost is 0.8818734288215637
# Current Validation Accuracy is 0.7038000226020813
#
# -------------------------------------------------------------------------------------
# Epoch 15, CIFAR-10 Batch 2:
# Current Training Cost is 0.24624335765838623
# Current Accuracy is 0.925000011920929
#
# Current Validation Cost is 0.872727632522583
# Current Validation Accuracy is 0.7056000232696533
#
# -------------------------------------------------------------------------------------
# Epoch 15, CIFAR-10 Batch 3:
# Current Training Cost is 0.17716938257217407
# Current Accuracy is 0.9750000238418579
#
# Current Validation Cost is 0.8849730491638184
# Current Validation Accuracy is 0.704800009727478
#
# -------------------------------------------------------------------------------------
# Epoch 15, CIFAR-10 Batch 4:
# Current Training Cost is 0.25245070457458496
# Current Accuracy is 0.925000011920929
#
# Current Validation Cost is 0.8995330929756165
# Current Validation Accuracy is 0.7044000029563904
#
# -------------------------------------------------------------------------------------
# Epoch 15, CIFAR-10 Batch 5:
# Current Training Cost is 0.21779251098632812
# Current Accuracy is 1.0
#
# Current Validation Cost is 0.9055283069610596
# Current Validation Accuracy is 0.6988000273704529
#
# -------------------------------------------------------------------------------------
# Epoch 16, CIFAR-10 Batch 1:
# Current Training Cost is 0.22971296310424805
# Current Accuracy is 0.9750000238418579
#
# Current Validation Cost is 0.8959290981292725
# Current Validation Accuracy is 0.7067999839782715
#
# -------------------------------------------------------------------------------------
# Epoch 16, CIFAR-10 Batch 2:
# Current Training Cost is 0.18107888102531433
# Current Accuracy is 0.949999988079071
#
# Current Validation Cost is 0.8806531429290771
# Current Validation Accuracy is 0.7113999724388123
#
# -------------------------------------------------------------------------------------
# Epoch 16, CIFAR-10 Batch 3:
# Current Training Cost is 0.12707838416099548
# Current Accuracy is 1.0
#
# Current Validation Cost is 0.8831759691238403
# Current Validation Accuracy is 0.7095999717712402
#
# -------------------------------------------------------------------------------------
# Epoch 16, CIFAR-10 Batch 4:
# Current Training Cost is 0.20306769013404846
# Current Accuracy is 0.9750000238418579
#
# Current Validation Cost is 0.922559380531311
# Current Validation Accuracy is 0.6980000138282776
#
# -------------------------------------------------------------------------------------
# Epoch 16, CIFAR-10 Batch 5:
# Current Training Cost is 0.1790938824415207
# Current Accuracy is 0.9750000238418579
#
# Current Validation Cost is 0.8682246804237366
# Current Validation Accuracy is 0.7074000239372253
#
# -------------------------------------------------------------------------------------
# Epoch 17, CIFAR-10 Batch 1:
# Current Training Cost is 0.33262893557548523
# Current Accuracy is 0.8500000238418579
#
# Current Validation Cost is 0.9043814539909363
# Current Validation Accuracy is 0.7017999887466431
#
# -------------------------------------------------------------------------------------
# Epoch 17, CIFAR-10 Batch 2:
# Current Training Cost is 0.18683381378650665
# Current Accuracy is 0.925000011920929
#
# Current Validation Cost is 0.9279062747955322
# Current Validation Accuracy is 0.6990000009536743
#
# -------------------------------------------------------------------------------------
# Epoch 17, CIFAR-10 Batch 3:
# Current Training Cost is 0.12670063972473145
# Current Accuracy is 1.0
#
# Current Validation Cost is 0.8925172090530396
# Current Validation Accuracy is 0.7067999839782715
#
# -------------------------------------------------------------------------------------
# Epoch 17, CIFAR-10 Batch 4:
# Current Training Cost is 0.12887486815452576
# Current Accuracy is 0.9750000238418579
#
# Current Validation Cost is 0.917504608631134
# Current Validation Accuracy is 0.7120000123977661
#
# -------------------------------------------------------------------------------------
# Epoch 17, CIFAR-10 Batch 5:
# Current Training Cost is 0.14576086401939392
# Current Accuracy is 1.0
#
# Current Validation Cost is 0.9211151599884033
# Current Validation Accuracy is 0.7035999894142151
#
# -------------------------------------------------------------------------------------
# Epoch 18, CIFAR-10 Batch 1:
# Current Training Cost is 0.2694251239299774
# Current Accuracy is 0.949999988079071
#
# Current Validation Cost is 0.9550002217292786
# Current Validation Accuracy is 0.7016000151634216
#
# -------------------------------------------------------------------------------------
# Epoch 18, CIFAR-10 Batch 2:
# Current Training Cost is 0.1634868085384369
# Current Accuracy is 0.949999988079071
#
# Current Validation Cost is 0.906149685382843
# Current Validation Accuracy is 0.7059999704360962
#
# -------------------------------------------------------------------------------------
# Epoch 18, CIFAR-10 Batch 3:
# Current Training Cost is 0.08983248472213745
# Current Accuracy is 1.0
#
# Current Validation Cost is 0.9133121967315674
# Current Validation Accuracy is 0.7116000056266785
#
# -------------------------------------------------------------------------------------
# Epoch 18, CIFAR-10 Batch 4:
# Current Training Cost is 0.18043768405914307
# Current Accuracy is 0.949999988079071
#
# Current Validation Cost is 0.9046794772148132
# Current Validation Accuracy is 0.7052000164985657
#
# -------------------------------------------------------------------------------------
# Epoch 18, CIFAR-10 Batch 5:
# Current Training Cost is 0.12436340004205704
# Current Accuracy is 1.0
#
# Current Validation Cost is 0.9404029250144958
# Current Validation Accuracy is 0.7017999887466431
#
# -------------------------------------------------------------------------------------
# Epoch 19, CIFAR-10 Batch 1:
# Current Training Cost is 0.20069272816181183
# Current Accuracy is 0.9750000238418579
#
# Current Validation Cost is 0.9724898338317871
# Current Validation Accuracy is 0.7075999975204468
#
# -------------------------------------------------------------------------------------
# Epoch 19, CIFAR-10 Batch 2:
# Current Training Cost is 0.1686158925294876
# Current Accuracy is 0.949999988079071
#
# Current Validation Cost is 0.9570902585983276
# Current Validation Accuracy is 0.7006000280380249
#
# -------------------------------------------------------------------------------------
# Epoch 19, CIFAR-10 Batch 3:
# Current Training Cost is 0.10963497310876846
# Current Accuracy is 1.0
#
# Current Validation Cost is 0.9130265712738037
# Current Validation Accuracy is 0.7093999981880188
#
# -------------------------------------------------------------------------------------
# Epoch 19, CIFAR-10 Batch 4:
# Current Training Cost is 0.11769551038742065
# Current Accuracy is 0.9750000238418579
#
# Current Validation Cost is 0.9245796799659729
# Current Validation Accuracy is 0.7071999907493591
#
# -------------------------------------------------------------------------------------
# Epoch 19, CIFAR-10 Batch 5:
# Current Training Cost is 0.12138982117176056
# Current Accuracy is 1.0
#
# Current Validation Cost is 0.9498589634895325
# Current Validation Accuracy is 0.6931999921798706
#
# -------------------------------------------------------------------------------------
# Epoch 20, CIFAR-10 Batch 1:
# Current Training Cost is 0.18404383957386017
# Current Accuracy is 0.949999988079071
#
# Current Validation Cost is 0.936217188835144
# Current Validation Accuracy is 0.7128000259399414
#
# -------------------------------------------------------------------------------------
# Epoch 20, CIFAR-10 Batch 2:
# Current Training Cost is 0.13463731110095978
# Current Accuracy is 0.9750000238418579
#
# Current Validation Cost is 0.9329532980918884
# Current Validation Accuracy is 0.7124000191688538
#
# -------------------------------------------------------------------------------------
# Epoch 20, CIFAR-10 Batch 3:
# Current Training Cost is 0.09528384357690811
# Current Accuracy is 1.0
#
# Current Validation Cost is 0.9602803587913513
# Current Validation Accuracy is 0.6988000273704529
#
# -------------------------------------------------------------------------------------
# Epoch 20, CIFAR-10 Batch 4:
# Current Training Cost is 0.10491399466991425
# Current Accuracy is 0.9750000238418579
#
# Current Validation Cost is 0.9677631855010986
# Current Validation Accuracy is 0.7008000016212463
#
# -------------------------------------------------------------------------------------
# Epoch 20, CIFAR-10 Batch 5:
# Current Training Cost is 0.12299816310405731
# Current Accuracy is 1.0
#
# Current Validation Cost is 0.9738464951515198
# Current Validation Accuracy is 0.699999988079071
#
# -------------------------------------------------------------------------------------
# Epoch 21, CIFAR-10 Batch 1:
# Current Training Cost is 0.1836356222629547
# Current Accuracy is 0.9750000238418579
#
# Current Validation Cost is 0.9478201866149902
# Current Validation Accuracy is 0.6991999745368958
#
# -------------------------------------------------------------------------------------
# Epoch 21, CIFAR-10 Batch 2:
# Current Training Cost is 0.168426051735878
# Current Accuracy is 0.925000011920929
#
# Current Validation Cost is 0.9550228714942932
# Current Validation Accuracy is 0.7056000232696533
#
# -------------------------------------------------------------------------------------
# Epoch 21, CIFAR-10 Batch 3:
# Current Training Cost is 0.0842120498418808
# Current Accuracy is 0.9750000238418579
#
# Current Validation Cost is 1.0241026878356934
# Current Validation Accuracy is 0.6990000009536743
#
# -------------------------------------------------------------------------------------
# Epoch 21, CIFAR-10 Batch 4:
# Current Training Cost is 0.11289751529693604
# Current Accuracy is 0.9750000238418579
#
# Current Validation Cost is 0.9591912031173706
# Current Validation Accuracy is 0.7092000246047974
#
# -------------------------------------------------------------------------------------
# Epoch 21, CIFAR-10 Batch 5:
# Current Training Cost is 0.11508133262395859
# Current Accuracy is 1.0
#
# Current Validation Cost is 0.9314290881156921
# Current Validation Accuracy is 0.7125999927520752
#
# -------------------------------------------------------------------------------------
# Epoch 22, CIFAR-10 Batch 1:
# Current Training Cost is 0.2237342894077301
# Current Accuracy is 0.8999999761581421
#
# Current Validation Cost is 1.0570405721664429
# Current Validation Accuracy is 0.6782000064849854
#
# -------------------------------------------------------------------------------------
# Epoch 22, CIFAR-10 Batch 2:
# Current Training Cost is 0.1270650178194046
# Current Accuracy is 0.9750000238418579
#
# Current Validation Cost is 0.9479363560676575
# Current Validation Accuracy is 0.7128000259399414
#
# -------------------------------------------------------------------------------------
# Epoch 22, CIFAR-10 Batch 3:
# Current Training Cost is 0.07532908767461777
# Current Accuracy is 1.0
#
# Current Validation Cost is 0.9828826189041138
# Current Validation Accuracy is 0.7027999758720398
#
# -------------------------------------------------------------------------------------
# Epoch 22, CIFAR-10 Batch 4:
# Current Training Cost is 0.09342783689498901
# Current Accuracy is 0.9750000238418579
#
# Current Validation Cost is 0.9424914121627808
# Current Validation Accuracy is 0.7102000117301941
#
# -------------------------------------------------------------------------------------
# Epoch 22, CIFAR-10 Batch 5:
# Current Training Cost is 0.08369120210409164
# Current Accuracy is 1.0
#
# Current Validation Cost is 0.9370638728141785
# Current Validation Accuracy is 0.7111999988555908
#
# -------------------------------------------------------------------------------------
# Epoch 23, CIFAR-10 Batch 1:
# Current Training Cost is 0.11658352613449097
# Current Accuracy is 0.9750000238418579
#
# Current Validation Cost is 1.0171077251434326
# Current Validation Accuracy is 0.7081999778747559
#
# -------------------------------------------------------------------------------------
# Epoch 23, CIFAR-10 Batch 2:
# Current Training Cost is 0.10475526005029678
# Current Accuracy is 1.0
#
# Current Validation Cost is 0.9548736214637756
# Current Validation Accuracy is 0.7120000123977661
#
# -------------------------------------------------------------------------------------
# Epoch 23, CIFAR-10 Batch 3:
# Current Training Cost is 0.06666481494903564
# Current Accuracy is 1.0
#
# Current Validation Cost is 0.9806371331214905
# Current Validation Accuracy is 0.7089999914169312
#
# -------------------------------------------------------------------------------------
# Epoch 23, CIFAR-10 Batch 4:
# Current Training Cost is 0.0735149085521698
# Current Accuracy is 1.0
#
# Current Validation Cost is 0.9537482261657715
# Current Validation Accuracy is 0.7116000056266785
#
# -------------------------------------------------------------------------------------
# Epoch 23, CIFAR-10 Batch 5:
# Current Training Cost is 0.09556378424167633
# Current Accuracy is 1.0
#
# Current Validation Cost is 0.9857929944992065
# Current Validation Accuracy is 0.7031999826431274
#
# -------------------------------------------------------------------------------------
# Epoch 24, CIFAR-10 Batch 1:
# Current Training Cost is 0.15295270085334778
# Current Accuracy is 0.949999988079071
#
# Current Validation Cost is 1.019632339477539
# Current Validation Accuracy is 0.7063999772071838
#
# -------------------------------------------------------------------------------------
# Epoch 24, CIFAR-10 Batch 2:
# Current Training Cost is 0.10167427361011505
# Current Accuracy is 1.0
#
# Current Validation Cost is 1.0487998723983765
# Current Validation Accuracy is 0.6973999738693237
#
# -------------------------------------------------------------------------------------
# Epoch 24, CIFAR-10 Batch 3:
# Current Training Cost is 0.06756950169801712
# Current Accuracy is 1.0
#
# Current Validation Cost is 1.0181236267089844
# Current Validation Accuracy is 0.7062000036239624
#
# -------------------------------------------------------------------------------------
# Epoch 24, CIFAR-10 Batch 4:
# Current Training Cost is 0.12721897661685944
# Current Accuracy is 0.9750000238418579
#
# Current Validation Cost is 1.0100736618041992
# Current Validation Accuracy is 0.6923999786376953
#
# -------------------------------------------------------------------------------------
# Epoch 24, CIFAR-10 Batch 5:
# Current Training Cost is 0.0797790139913559
# Current Accuracy is 1.0
#
# Current Validation Cost is 0.9898869395256042
# Current Validation Accuracy is 0.7088000178337097
#
# -------------------------------------------------------------------------------------
# Epoch 25, CIFAR-10 Batch 1:
# Current Training Cost is 0.11680331081151962
# Current Accuracy is 1.0
#
# Current Validation Cost is 1.0616415739059448
# Current Validation Accuracy is 0.6904000043869019
#
# -------------------------------------------------------------------------------------
# Epoch 25, CIFAR-10 Batch 2:
# Current Training Cost is 0.10078243911266327
# Current Accuracy is 0.9750000238418579
#
# Current Validation Cost is 0.9864884614944458
# Current Validation Accuracy is 0.7053999900817871
#
# -------------------------------------------------------------------------------------
# Epoch 25, CIFAR-10 Batch 3:
# Current Training Cost is 0.03244251757860184
# Current Accuracy is 1.0
#
# Current Validation Cost is 0.98856121301651
# Current Validation Accuracy is 0.7131999731063843
#
# -------------------------------------------------------------------------------------
# Epoch 25, CIFAR-10 Batch 4:
# Current Training Cost is 0.05232395604252815
# Current Accuracy is 1.0
#
# Current Validation Cost is 0.9975284934043884
# Current Validation Accuracy is 0.7092000246047974
#
# -------------------------------------------------------------------------------------
# Epoch 25, CIFAR-10 Batch 5:
# Current Training Cost is 0.09475686401128769
# Current Accuracy is 1.0
#
# Current Validation Cost is 1.0612287521362305
# Current Validation Accuracy is 0.6830000281333923
#
# -------------------------------------------------------------------------------------

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.6968947784810127

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. That's because there are many more techniques that can be applied to your model and we recemmond that once you are done with this project, you explore!
#
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
